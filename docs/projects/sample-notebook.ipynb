# %% [markdown]
# <!--
# CHECKLIST FOR THIS NOTEBOOK (copy this file for each new notebook project):
# - [ ] Replace [YOUR PROJECT TITLE] with your project title
# - [ ] Update the Overview section
# - [ ] Update the Methods & Tools section
# - [ ] Replace placeholder data with your real data
# - [ ] Update the Key Findings section
# - [ ] Update the Links section
# - [ ] Add a card for this project on docs/projects/index.md
# - [ ] Add a nav entry in mkdocs.yml
# -->
#
# # Sample Notebook
#
# ## Overview
#
# [One or two sentences describing what you did, what data you used, and why it matters.]
#
# **Study Area:** [Region or extent]
# **Duration:** [Start month/year – End month/year]
# **Role:** [Solo project / Team lead / Contributor]
# **Status:** [Completed / In progress]

# %% [markdown]
# ---
#
# ## Methods & Tools
#
# **Data Sources**
#
# - [Dataset name and source]
# - [Dataset name and source]
#
# **Processing Steps**
#
# 1. Load and clean raw data
# 2. Compute summary statistics
# 3. Visualise trends with a pandas chart
# 4. Map spatial distribution with Folium
#
# **Tools Used**
#
# | Tool | Purpose |
# |------|---------|
# | pandas | Data loading, cleaning, aggregation |
# | matplotlib | Static charts |
# | folium | Interactive web maps |

# %% [markdown]
# ---
#
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# ---
#
# ## Data
#
# Placeholder dataset — replace with your own CSV, GeoJSON, or API call.

# %%
# Placeholder time-series data
# Replace with: df = pd.read_csv("your_data.csv")
data = {
    "month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
              "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "metric_a": [120, 135, 148, 162, 175, 190, 185, 178, 160, 145, 130, 118],
    "metric_b": [ 80,  88,  95, 105, 112, 120, 118, 110, 100,  92,  85,  78],
}

df = pd.DataFrame(data)
df.head()

# %% [markdown]
# ---
#
# ## Analysis
#
# ### Summary statistics

# %%
df[["metric_a", "metric_b"]].describe()

# %% [markdown]
# ### Trend chart

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(df["month"], df["metric_a"], marker="o", label="Metric A", color="steelblue")
ax.plot(df["month"], df["metric_b"], marker="s", label="Metric B", color="coral")

ax.set_title("[YOUR CHART TITLE]", fontsize=14, fontweight="bold")
ax.set_xlabel("Month")
ax.set_ylabel("[Unit]")
ax.legend()
ax.grid(axis="y", linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Grouped bar chart

# %% [markdown]
# ---
#
# ## Spatial Distribution
#
# Interactive map of placeholder sample points — replace coordinates and popup text with your own data.

# %%
# Placeholder point locations
# Replace with your own lat/lon data, e.g. from a GeoDataFrame or CSV
sites = pd.DataFrame({
    "name":  ["Site A", "Site B", "Site C", "Site D", "Site E"],
    "lat":   [28.61,    28.65,    28.58,    28.70,    28.55],
    "lon":   [77.20,    77.23,    77.17,    77.28,    77.15],
    "value": [142,      168,      95,       210,       87],
})

# Centre the map on the mean location
m = folium.Map(
    location=[sites["lat"].mean(), sites["lon"].mean()],
    zoom_start=11,
    tiles="CartoDB positron",
)

# Add a CircleMarker for each site, scaled by value
for _, row in sites.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=row["value"] / 20,          # scale radius to value
        color="steelblue",
        fill=True,
        fill_opacity=0.7,
        tooltip=f"{row['name']}: {row['value']}",
        popup=folium.Popup(
            f"<b>{row['name']}</b><br>Value: {row['value']}",
            max_width=200,
        ),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a08ff0c1fd8d31138309664df9d7fb9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a08ff0c1fd8d31138309664df9d7fb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a08ff0c1fd8d31138309664df9d7fb9 = L.map(
#                 &quot;map_0a08ff0c1fd8d31138309664df9d7fb9&quot;,
#                 {
#                     center: [28.618000000000002, 77.20599999999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e05aac346d87fa14bea1541ac9843cf6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e05aac346d87fa14bea1541ac9843cf6.addTo(map_0a08ff0c1fd8d31138309664df9d7fb9);
#
#
#             var circle_marker_e7a4bcad8f05be2d75c6604dfdb47832 = L.circleMarker(
#                 [28.61, 77.2],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;steelblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;steelblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a08ff0c1fd8d31138309664df9d7fb9);
#
#
#         var popup_ade9e1d097e93357bde25a8e846b93d8 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_0d9334ac408f23642edf9a801405ce06 = $(`&lt;div id=&quot;html_0d9334ac408f23642edf9a801405ce06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Site A&lt;/b&gt;&lt;br&gt;Value: 142&lt;/div&gt;`)[0];
#                 popup_ade9e1d097e93357bde25a8e846b93d8.setContent(html_0d9334ac408f23642edf9a801405ce06);
#
#
#
#         circle_marker_e7a4bcad8f05be2d75c6604dfdb47832.bindPopup(popup_ade9e1d097e93357bde25a8e846b93d8)
#         ;
#
#
#
#
#             circle_marker_e7a4bcad8f05be2d75c6604dfdb47832.bindTooltip(
#                 `&lt;div&gt;
#                      Site A: 142
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_fa59e60673069bfa917fbfc9c2634bbd = L.circleMarker(
#                 [28.65, 77.23],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;steelblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;steelblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a08ff0c1fd8d31138309664df9d7fb9);
#
#
#         var popup_1bf689258395388a734668216891c526 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_5d3fd940c25c1e9b48c0fb3e6e7b2c77 = $(`&lt;div id=&quot;html_5d3fd940c25c1e9b48c0fb3e6e7b2c77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Site B&lt;/b&gt;&lt;br&gt;Value: 168&lt;/div&gt;`)[0];
#                 popup_1bf689258395388a734668216891c526.setContent(html_5d3fd940c25c1e9b48c0fb3e6e7b2c77);
#
#
#
#         circle_marker_fa59e60673069bfa917fbfc9c2634bbd.bindPopup(popup_1bf689258395388a734668216891c526)
#         ;
#
#
#
#
#             circle_marker_fa59e60673069bfa917fbfc9c2634bbd.bindTooltip(
#                 `&lt;div&gt;
#                      Site B: 168
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e5d142f7d21753cddb06cb6d7d44cb0f = L.circleMarker(
#                 [28.58, 77.17],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;steelblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;steelblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.75, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a08ff0c1fd8d31138309664df9d7fb9);
#
#
#         var popu

# %% [markdown]
# ---
#
# ## Key Findings
#
# - [Finding one — include a number or metric if possible]
# - [Finding two]
# - [Finding three]
#
# ---
#
# ## Links
#
# [View Code on GitHub](https://github.com/[YOUR-GITHUB-USERNAME]/[YOUR-REPO-NAME])
# [View Data Source](https://example.com)
